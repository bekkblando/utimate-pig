# %%
import matplotlib.pyplot as plt
import player
from player import Game, Player
import statistics as stats

# %%
def start():
    gm1 = Game()
    player1 = Player()
    for number in range(7):
        gm1.turn(player1)
    return player1.player_points
    
data = [start() for item in range(200)]
print(data)
# Out:
# [80, 102, 24, 0, 79, 54, 0, 73, 0, 46, 49, 91, 21, 73, 45, 70, 57, 0, 64, 75, 31, 48, 79, 91, 26, 41, 0, 41, 45, 47, 70, 38, 84, 75, 32, 57, 51, 62, 23, 15, 61, 69, 103, 68, 78, 27, 51, 72, 40, 56, 70, 19, 102, 92, 20, 79, 46, 49, 56, 124, 95, 49, 47, 41, 25, 28, 17, 17, 70, 29, 50, 41, 100, 42, 47, 128, 59, 0, 26, 25, 75, 71, 54, 70, 72, 67, 91, 50, 49, 72, 72, 50, 80, 52, 63, 0, 47, 102, 82, 45, 97, 79, 0, 67, 103, 62, 82, 42, 43, 49, 107, 46, 106, 99, 44, 43, 72, 122, 22, 0, 26, 0, 110, 70, 16, 24, 70, 0, 71, 50, 23, 78, 0, 22, 21, 0, 50, 37, 69, 81, 65, 89, 71, 0, 17, 47, 45, 69, 0, 51, 96, 44, 45, 46, 0, 40, 83, 29, 51, 42, 67, 106, 99, 110, 54, 21, 30, 27, 98, 91, 51, 87, 48, 67, 25, 21, 28, 60, 98, 51, 57, 90, 76, 0, 72, 0, 43, 0, 26, 47, 0, 55, 45, 68, 69, 30, 0, 137, 70, 106]

# %%
# %matplotlib inline

# %%
plt.hist(data, bins=20)
plt.xlabel("Points")
plt.ylabel("Commanality of Points")
plt.title("Rule 1 Per Turn")
plt.show()

# %%
plt.hist(data, bins=20)
plt.xlabel("Points")
plt.ylabel("Commanality of Points")
plt.title("Rule 2 Per Turn")
plt.show()

# %%
plt.hist(data, bins=20)
plt.xlabel("Points")
plt.ylabel("Commanality of Points")
plt.title("Rule 3 Per Turn")
plt.show()

# %%
plt.hist(data, bins=20)
plt.xlabel("Points")
plt.ylabel("Commanality of Points")
plt.title("Rule 4 Per Turn")
plt.show()

# %%
plt.hist(data, bins=20)
plt.xlabel("Points")
plt.ylabel("Commanality of Points")
plt.title("Rule 5 Per Turn")
plt.show()

# %%
plt.hist(data, bins=20)
plt.xlabel("Points")
plt.ylabel("Commanality of Points")
plt.title("Rule 6 Per Turn")
plt.show()

# %%
ping_pong = [7, 8, 4, 3, 5]
plt.hist(ping_pong, bins=5)
plt.xlabel("number")
plt.ylabel("frequency")
plt.title("Normal Distribution")
plt.show()

# %%
bekk_foos_ball = [8, 7, 1, 2, 2, 2, 6, 3, 2]
foos_ball = [1, 2, 2, 1, 2, 1, 5, 1, 1]
plt.plot(bekk_foos_ball)
plt.plot(foos_ball)
plt.plot()
plt.xticks(range(6), )
plt.xlabel("Rounds")
plt.ylabel("More hits")
plt.title("Coin")
plt.legend(["Bekks", "Kevin"], loc='upper left')
plt.show()
